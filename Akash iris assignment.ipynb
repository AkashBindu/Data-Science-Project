# %%
# Read the dataset to python environment
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
file = "C:/Users/ppbin/OneDrive/Desktop/iris.xls"

# %%
data = pd.read_excel(file) #reading file

# %%
# Display the columns in the dataset
print(data)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# display headings
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
import pandas as mypd
import matplotlib.pyplot as myplot
import seaborn as sns

# %%
SL=data.SL

# %%
SL
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
# Calculate the mean of each column of the dataset

# %%
# Calculate the mean of SL
SL_mean=SL.mean()

# %%
SL_mean
# Out:
# 5.843333333333334

# %%
SW=data.SW

# %%
SW
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
# Calculate the mean of SW
SW_mean=SW.mean()
SW_mean
# Out:
# 3.0540000000000003

# %%
# Calculate the mean of PL
PL=data.PL
PL_mean=PL.mean()
PL_mean
# Out:
# 3.758666666666666

# %%
# Calculate the mean of PW
PW=data.PW
PW_mean=PW.mean()
PW_mean
# Out:
# 1.1986666666666668

# %%
# Check for the null values present in the dataset

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.count()
# Out:
# SL                150
# SW                150
# PL                150
# PW                150
# Classification    150
# dtype: int64

# %%
data.var()
# Out:
# C:\Users\ppbin\AppData\Local\Temp\ipykernel_8772\445316826.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# SL    0.685694
# SW    0.188004
# PL    3.113179
# PW    0.582414
# dtype: float64

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.skew()
# Out:
# C:\Users\ppbin\AppData\Local\Temp\ipykernel_8772\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# SL    0.314911
# SW    0.334053
# PL   -0.274464
# PW   -0.104997
# dtype: float64

# %%
data.kurt()
# Out:
# C:\Users\ppbin\AppData\Local\Temp\ipykernel_8772\2907027414.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurt()
# SL   -0.552064
# SW    0.290781
# PL   -1.401921
# PW   -1.339754
# dtype: float64

# %%
# Perform meaningful visualizations using the dataset

# %%
import matplotlib.pyplot as plot
import seaborn as sns

# %%
# Histogram of SL
plot.hist(SL)
plot.title("Histogram")
plot.xlabel("SL")
plot.ylabel("Frequency")
plot.show()

# %%
#Boxplot of Sl
plot.boxplot(SL)
plot.title("BoxPlot")
plot.xlabel("SL")
plot.show()

# %%
#scatter plot of SL and SW
plot.scatter(SL,SW)
plot.title("ScatterPlot")
plot.xlabel('SL')
plot.ylabel('SW')
plot.show()

# %%
# Histogram of SW
plot.hist(SW)
plot.title("Histogram")
plot.xlabel("SW")
plot.ylabel("Frequency")
plot.show()

# %%
#Boxplot of SW
plot.boxplot(SW)
plot.title("BoxPlot")
plot.xlabel("SW")
plot.show()

# %%
plot.hist(PL)
plot.title("Histogram")
plot.xlabel("PL")
plot.ylabel("Frequency")
plot.show()

# %%
#Boxplot of PL
plot.boxplot(PL)
plot.title("BoxPlot")
plot.xlabel("PL")
plot.show()

# %%
plot.hist(PW)
plot.title("Histogram")
plot.xlabel("PW")
plot.ylabel("Frequency")
plot.show()

# %%
#Boxplot of Sl
plot.boxplot(PW)
plot.title("BoxPlot")
plot.xlabel("PW")
plot.show()

# %%
#scatter plot of SL and SW
plot.scatter(PL,PW)
plot.title("ScatterPlot")
plot.xlabel('PL')
plot.ylabel('PW')
plot.show()

# %%
#scatter plot of PL and SL
plot.scatter(PL,SL)
plot.title("ScatterPlot")
plot.xlabel('PL')
plot.ylabel('SL')
plot.show()

# %%
#scatter plot of PL and SL
plot.scatter(PW,SW)
plot.title("ScatterPlot")
plot.xlabel('PW')
plot.ylabel('SW')
plot.show()

# %%
# A seaborn jointplot shows bivariate scatterplots and univariate histograms in the 
# same figure
sns.jointplot(x="SL", y="SW", data=data, size=15)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.FacetGrid(data, hue="Classification", palette="husl", size=5) \
#       2    .map(plt.scatter, "SL", "SW") \
#       3    .add_legend()
#
# TypeError: FacetGrid.__init__() got an unexpected keyword argument 'size'

# %%
data["Classification"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
sns.FacetGrid(data, hue="Classification", palette="husl") \
   .map(plot.scatter, "SL", "SW") \
   .add_legend()

# %%
sns.FacetGrid(data, hue="Classification", palette="husl") \
   .map(plot.scatter, "PL", "PW") \
   .add_legend()

# %%
#  boxplot of PL for classification
sns.boxplot(x="Classification", y="PL", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='PL'>

# %%
#  boxplot of PW for classification

sns.boxplot(x="Classification", y="PW", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='PW'>

# %%
#  boxplot of SL for classification
sns.boxplot(x="Classification", y="SL", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SL'>

# %%
#  boxplot of SW for classification
sns.boxplot(x="Classification", y="SW", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SW'>

# %%
#  violinplot of PL-- this shows the density of data at each primary split
sns.violinplot(x="Classification", y="PL", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='PL'>

# %%
#  violinplot of PW-- this shows the density of data at each primary split
sns.violinplot(x="Classification", y="PW", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='PW'>

# %%
#  violinplot of SL-- this shows the density of data at each primary split
sns.violinplot(x="Classification", y="SL", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SL'>

# %%
#  violinplot of SW-- this shows the density of data at each primary split
sns.violinplot(x="Classification", y="SW", palette="husl", data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SW'>

# %%
# violinplot-PL with data points shown inside
sns.violinplot(x="Classification", y="PL", palette="husl", data=data)
sns.swarmplot(x="Classification", y="PL", data=data, color="w", alpha=.9);
# Out:
# C:\Users\ppbin\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# violinplot-PW with data points shown inside
sns.violinplot(x="Classification", y="PW", palette="husl", data=data)
sns.swarmplot(x="Classification", y="PW", data=data, color="w", alpha=.9);
# Out:
# C:\Users\ppbin\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ppbin\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# violinplot-SL with data points shown inside
sns.violinplot(x="Classification", y="SL", palette="husl", data=data)
sns.swarmplot(x="Classification", y="SL", data=data, color="w", alpha=.9);

# %%
# violinplot-PW with data points shown inside
sns.violinplot(x="Classification", y="SW", palette="husl", data=data)
sns.swarmplot(x="Classification", y="SW", data=data, color="w", alpha=.9);

# %%
#  pairplot, which shows the bivariate relation
sns.pairplot(data, hue="Classification", palette="husl", size=3)
# Out:
# C:\Users\ppbin\anaconda3\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data.boxplot(by="Classification", figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'PL'}, xlabel='[Classification]'>,
#         <Axes: title={'center': 'PW'}, xlabel='[Classification]'>],
#        [<Axes: title={'center': 'SL'}, xlabel='[Classification]'>,
#         <Axes: title={'center': 'SW'}, xlabel='[Classification]'>]],
#       dtype=object)

# %%
# Andrews Curves 
import pandas as pd
from pandas.plotting import andrews_curves
andrews_curves(data, "Classification")
# Out:
# <Axes: >

# %%
# Parallel coordinates plots each feature on a separate column & then draws lines
# connecting the features for each data sample
from pandas.plotting import parallel_coordinates
parallel_coordinates(data, "Classification")
# Out:
# <Axes: >

# %%
#  multivariate visualization technique pandas has is radviz
# Which puts each feature as a point on a 2D plane, and then simulates
# having each sample attached to those points through a spring weighted
# by the relative value for that feature
from pandas.plotting import radviz
radviz(data, "Classification")
# Out:
# <Axes: >
